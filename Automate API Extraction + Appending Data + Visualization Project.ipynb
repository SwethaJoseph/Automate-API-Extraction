# %% [markdown]
# ## Automate API Extraction + Appending Data + Visualization Project

# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

# %%
type(data)
# Out:
# dict

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
      #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)

    
    # Use this if you just want to keep it in a dataframe
    #df2 = pd.json_normalize(data['data'])
    #df2['Timestamp'] = pd.to_datetime('now')
    #df = df.append(df2)


    # Use this if you want to create a csv and append data to it
    df = pd.json_normalize(data['data'])
    df['timestamp'] = pd.to_datetime('now')
    df

    if not os.path.isfile(r'C:\Users\sweth\OneDrive\Documents\Python Project\csv files\API.csv'):
        df.to_csv(r'C:\Users\sweth\OneDrive\Documents\Python Project\csv files\API.csv', header='column_names')
    else:
        df.to_csv(r'C:\Users\sweth\OneDrive\Documents\Python Project\csv files\API.csv', mode='a', header=False)
        
    #Then to read in the file: df = pd.read_csv(r'C:\Users\sweth\OneDrive\Documents\Python Project\csv files\API.csv')

# %%
import os 
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner completed')
    sleep(60) #sleep for 1 minute
exit()

# %%
df72 = pd.read_csv(r'C:\Users\sweth\OneDrive\Documents\Python Project\csv files\API.csv')
df72
# Out:
#      Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0             0      1      Bitcoin    BTC       bitcoin             11595
# 1             1   1027     Ethereum    ETH      ethereum              9126
# 2             2    825  Tether USDt   USDT        tether             91251
# 3             3   1839          BNB    BNB           bnb              2190
# 4             4   5426       Solana    SOL        solana               699
# 5             5   3408         USDC   USDC      usd-coin             20893
# 6             6     52          XRP    XRP           xrp              1351
# 7             7  11419      Toncoin    TON       toncoin               454
# 8             8     74     Dogecoin   DOGE      dogecoin              1021
# 9             9   2010      Cardano    ADA       cardano              1210
# 10           10   1958         TRON    TRX          tron               999
# ...

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11595
# 1    1027     Ethereum    ETH      ethereum              9126
# 2     825  Tether USDt   USDT        tether             91259
# 3    1839          BNB    BNB           bnb              2190
# 4    5426       Solana    SOL        solana               699
# 5    3408         USDC   USDC      usd-coin             20894
# 6      52          XRP    XRP           xrp              1351
# 7   11419      Toncoin    TON       toncoin               454
# 8      74     Dogecoin   DOGE      dogecoin              1021
# 9    2010      Cardano    ADA       cardano              1210
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               750
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
# One thing I noticed was the scientific notation. I like it, but I want to be able to see the numbers in this case

pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
df
# Out:
#        id         name symbol          slug  num_market_pairs  \
# 0       1      Bitcoin    BTC       bitcoin             11595
# 1    1027     Ethereum    ETH      ethereum              9126
# 2     825  Tether USDt   USDT        tether             91259
# 3    1839          BNB    BNB           bnb              2190
# 4    5426       Solana    SOL        solana               699
# 5    3408         USDC   USDC      usd-coin             20894
# 6      52          XRP    XRP           xrp              1351
# 7   11419      Toncoin    TON       toncoin               454
# 8      74     Dogecoin   DOGE      dogecoin              1021
# 9    2010      Cardano    ADA       cardano              1210
# 10   1958         TRON    TRX          tron               999
# 11   5805    Avalanche   AVAX     avalanche               750
# 12   5994    Shiba Inu   SHIB     shiba-inu               844
# 13   6636     Polkadot    DOT  polkadot-new               792
# ...

# %%
# Now let's look at the coin trends over time

df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()
df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.45177                       1.15080
# Ethereum                         0.27063                       2.01434
# Tether USDt                     -0.01490                      -0.01817
# BNB                             -0.14442                       2.08143
# Solana                          -0.02035                       1.19821
# USDC                            -0.00911                      -0.01651
# XRP                             -0.45887                       1.06788
# Toncoin                         -0.27020                       0.50776
# Dogecoin                        -0.16680                       1.41990
# Cardano                         -0.55222                       3.10948
# TRON                             0.09779                       1.34746
# Avalanche                       -1.35287                       3.47682
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.45177
#              quote.USD.percent_change_24h     1.15080
#              quote.USD.percent_change_7d     -4.19106
#              quote.USD.percent_change_30d   -16.68297
#              quote.USD.percent_change_60d    -5.02404
#              quote.USD.percent_change_90d   -17.52742
# Ethereum     quote.USD.percent_change_1h      0.27063
#              quote.USD.percent_change_24h     2.01434
#              quote.USD.percent_change_7d     -5.74679
#              quote.USD.percent_change_30d   -15.09431
#              quote.USD.percent_change_60d     7.17256
#              quote.USD.percent_change_90d   -11.39462
# Tether USDt  quote.USD.percent_change_1h     -0.01490
#              quote.USD.percent_change_24h    -0.01817
#              quote.USD.percent_change_7d      0.11574
#              quote.USD.percent_change_30d     0.00698
#              quote.USD.percent_change_60d     0.00658
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name='values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.45177
#             quote.USD.percent_change_24h   1.15080
#             quote.USD.percent_change_7d   -4.19106
#             quote.USD.percent_change_30d -16.68297
#             quote.USD.percent_change_60d  -5.02404
#             quote.USD.percent_change_90d -17.52742
# Ethereum    quote.USD.percent_change_1h    0.27063
#             quote.USD.percent_change_24h   2.01434
#             quote.USD.percent_change_7d   -5.74679
#             quote.USD.percent_change_30d -15.09431
#             quote.USD.percent_change_60d   7.17256
#             quote.USD.percent_change_90d -11.39462
# Tether USDt quote.USD.percent_change_1h   -0.01490
#             quote.USD.percent_change_24h  -0.01817
#             quote.USD.percent_change_7d    0.11574
#             quote.USD.percent_change_30d   0.00698
#             quote.USD.percent_change_60d   0.00658
# ...

# %%
type(df5)
# Out:
# pandas.core.frame.DataFrame

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

# Set the above DataFrame index object as the index
# using set_index() function
df6 = df5.reset_index()
df6

# If it only has the index and values try doing reset_index like "df5.reset_index()"
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.45177
# 1       Bitcoin  quote.USD.percent_change_24h   1.15080
# 2       Bitcoin   quote.USD.percent_change_7d  -4.19106
# 3       Bitcoin  quote.USD.percent_change_30d -16.68297
# 4       Bitcoin  quote.USD.percent_change_60d  -5.02404
# 5       Bitcoin  quote.USD.percent_change_90d -17.52742
# 6      Ethereum   quote.USD.percent_change_1h   0.27063
# 7      Ethereum  quote.USD.percent_change_24h   2.01434
# 8      Ethereum   quote.USD.percent_change_7d  -5.74679
# 9      Ethereum  quote.USD.percent_change_30d -15.09431
# 10     Ethereum  quote.USD.percent_change_60d   7.17256
# 11     Ethereum  quote.USD.percent_change_90d -11.39462
# 12  Tether USDt   quote.USD.percent_change_1h  -0.01490
# 13  Tether USDt  quote.USD.percent_change_24h  -0.01817
# 14  Tether USDt   quote.USD.percent_change_7d   0.11574
# 15  Tether USDt  quote.USD.percent_change_30d   0.00698
# ...

# %%
# Change the column name

df7 = df6.rename(columns={'level_1': 'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.45177
# 1       Bitcoin  quote.USD.percent_change_24h   1.15080
# 2       Bitcoin   quote.USD.percent_change_7d  -4.19106
# 3       Bitcoin  quote.USD.percent_change_30d -16.68297
# 4       Bitcoin  quote.USD.percent_change_60d  -5.02404
# 5       Bitcoin  quote.USD.percent_change_90d -17.52742
# 6      Ethereum   quote.USD.percent_change_1h   0.27063
# 7      Ethereum  quote.USD.percent_change_24h   2.01434
# 8      Ethereum   quote.USD.percent_change_7d  -5.74679
# 9      Ethereum  quote.USD.percent_change_30d -15.09431
# 10     Ethereum  quote.USD.percent_change_60d   7.17256
# 11     Ethereum  quote.USD.percent_change_90d -11.39462
# 12  Tether USDt   quote.USD.percent_change_1h  -0.01490
# 13  Tether USDt  quote.USD.percent_change_24h  -0.01817
# 14  Tether USDt   quote.USD.percent_change_7d   0.11574
# 15  Tether USDt  quote.USD.percent_change_30d   0.00698
# ...

# %%
df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['1h','24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.45177
# 1       Bitcoin            24h   1.15080
# 2       Bitcoin             7d  -4.19106
# 3       Bitcoin            30d -16.68297
# 4       Bitcoin            60d  -5.02404
# 5       Bitcoin            90d -17.52742
# 6      Ethereum             1h   0.27063
# 7      Ethereum            24h   2.01434
# 8      Ethereum             7d  -5.74679
# 9      Ethereum            30d -15.09431
# 10     Ethereum            60d   7.17256
# 11     Ethereum            90d -11.39462
# 12  Tether USDt             1h  -0.01490
# 13  Tether USDt            24h  -0.01817
# 14  Tether USDt             7d   0.11574
# 15  Tether USDt            30d   0.00698
# 16  Tether USDt            60d   0.00658
# 17  Tether USDt            90d  -0.03545
# 18          BNB             1h  -0.14442
# 19          BNB            24h   2.08143
# 20          BNB             7d  -5.86650
# 21          BNB            30d -18.36884
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x='percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df10 = df[['name','quote.USD.price','timestamp']]
df10 = df10.query("name == 'Bitcoin'")
df10
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      57842.22696 2024-07-10 14:08:09.434399

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df10)
